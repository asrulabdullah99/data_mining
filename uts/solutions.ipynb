# %%
#solution number 1
import pandas as pd 
data = pd.read_csv('dataset_uts.csv')
data
# Out:
#     No     Nama  Kehadiran  Tugas  UTS  UAS
# 0    1   Nama 1          6     17   20   14
# 1    2   Nama 2          8      2    0   34
# 2    3   Nama 3          3      6   23   11
# 3    4   Nama 4          8     16   12   23
# 4    5   Nama 5         10     10   16   27
# 5    6   Nama 6          9      9   12    1
# 6    7   Nama 7          1      5   18   24
# 7    8   Nama 8          3     20   19    0
# 8    9   Nama 9          9     20    0   40
# 9   10  Nama 10          2      0    1   40
# 10  11  Nama 11          6      0   21   22
# 11  12  Nama 12          3     19   25    1
# 12  13  Nama 13          9      8   17   22
# 13  14  Nama 14          1     15    6    2
# 14  15  Nama 15          9     14   26    0

# %%
x = data.iloc[:,2:6]
x
# Out:
#     Kehadiran  Tugas  UTS  UAS
# 0           6     17   20   14
# 1           8      2    0   34
# 2           3      6   23   11
# 3           8     16   12   23
# 4          10     10   16   27
# 5           9      9   12    1
# 6           1      5   18   24
# 7           3     20   19    0
# 8           9     20    0   40
# 9           2      0    1   40
# 10          6      0   21   22
# 11          3     19   25    1
# 12          9      8   17   22
# 13          1     15    6    2
# 14          9     14   26    0

# %%
x_axis = x.sum(axis=1)
x_axis
# Out:
# 0     57
# 1     44
# 2     43
# 3     59
# 4     63
# 5     31
# 6     48
# 7     42
# 8     69
# 9     43
# 10    49
# 11    48
# 12    56
# 13    24
# 14    49
# dtype: int64

# %%
import matplotlib.pyplot as plt 

y_axis = x_axis
x_name = data.iloc[:,1]
plt.bar(x_name,y_axis)
plt.show()

# %%
#solution number 2
data = pd.read_csv('titanic_dataset.csv')
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
from feature_engine.imputation import EndTailImputer
imputer = EndTailImputer(imputation_method='gaussian', tail='right')
imputer.fit(data)
transform_data = imputer.transform(data)
transform_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex       Age  \
# 0                              Braund, Mr. Owen Harris    male  22.00000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.00000
# 2                               Heikkinen, Miss. Laina  female  26.00000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.00000
# 4                             Allen, Mr. William Henry    male  35.00000
# ..                                                 ...     ...       ...
# ...

# %%
transform_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
from feature_engine.imputation import RandomSampleImputer

data_cat = pd.DataFrame(transform_data)
imputer = RandomSampleImputer(random_state=42)
imputer.fit(data_cat)
data2 = imputer.transform(data_cat)
data2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex       Age  \
# 0                              Braund, Mr. Owen Harris    male  22.00000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.00000
# 2                               Heikkinen, Miss. Laina  female  26.00000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.00000
# 4                             Allen, Mr. William Henry    male  35.00000
# ..                                                 ...     ...       ...
# ...

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        891 non-null    object
#  11  Embarked     891 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data2['Cabin']
# Out:
# 0       D21
# 1       C85
# 2       F38
# 3      C123
# 4       E10
#        ...
# 886     B86
# 887     B42
# 888     C45
# 889    C148
# 890    E101
# Name: Cabin, Length: 891, dtype: object
